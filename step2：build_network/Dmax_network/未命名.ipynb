# %%
# %run main.py
# Out:
# 训练次数：1, Loss: 1.2681819798226621
# 测试集Loss: 0.7439134589719336
# 训练次数：2, Loss: 0.633621607082853
# 测试集Loss: 0.6540525378915988
# 训练次数：3, Loss: 0.5968529475910136
# 测试集Loss: 0.61774414328275
# 训练次数：4, Loss: 0.5820256253266275
# 测试集Loss: 0.6598718177409099
# 训练次数：5, Loss: 0.5605242799418325
# 测试集Loss: 0.5928291913393182
# 训练次数：6, Loss: 0.5329626114339722
# 测试集Loss: 0.5571871731280814
# 训练次数：7, Loss: 0.536387218257247
# 测试集Loss: 0.5448920660002341
# 训练次数：8, Loss: 0.5334675491280882
# 测试集Loss: 0.5938349496630174
# 训练次数：9, Loss: 0.5465101952919331
# 测试集Loss: 0.5409095496885891
# 训练次数：10, Loss: 0.525580319957012
# 测试集Loss: 0.5384199951331305
# 训练次数：11, Loss: 0.506116167627837
# 测试集Loss: 0.5195187455414094
# 训练次数：12, Loss: 0.4707339251330132
# 测试集Loss: 0.5567620555379459
# 训练次数：13, Loss: 0.5090529457476612
# 测试集Loss: 0.5291926139081262
# 训练次数：14, Loss: 0.466287434897563
# 测试集Loss: 0.4893183466124214
# 训练次数：15, Loss: 0.45969025431841554
# 测试集Loss: 0.5003929574242131
# ...

# %%
# %run validate.py
# Out:
# D:\ANADONDA\envs\pytorch\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
